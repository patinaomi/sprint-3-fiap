# %% [markdown]
# <a href="https://colab.research.google.com/github/patinaomi/sprint-3-fiap/blob/main/questionario_fit_comercial_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PROJETO - IA - fit comercial. Teste para verificar qual dos produtos SALESforce melhor se adequa as necessidades do lead que está respondendo o questionário.

# %%
# Para trabalhar com dados em tabelas
import pandas as pd

# Para trabalhar com gráficos
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('formulario para teste IA_OK.csv', sep=';', encoding='utf-8') # Estamos carregando o arquivo csv usando o ; como separador

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.head()
# Out:
#      empresa  \
# 0  usuario 1
# 1  usuario 2
# 2  usuario 3
# 3  usuario 4
# 4  usuario 5
#
#    estrategias de marketing mais eficientes que mostrem nossa marca para nosso publico alvo  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    IA e automacoes para auxiliar nas atividades operacionais  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    desenvolver estrategias de atendimento eficientes  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    melhorar a comunicacao entre nossos clientes e nossa equipe de atendimento  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    ambiente integrado para manter as equipes 100 entrosadas  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    aumento da produtividade da equipe  \
# 0                                   3
# 1                                   3
# 2                                   4
# 3                                   4
# 4                                   3
#
#    melhorar a capacitacao das equipes de CRM  \
# 0                                          4
# 1                                          3
# 2                                          4
# 3                                          3
# 4                                          4
#
#    reducao no custo de suporte e atendimento ao clientes  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    aumentar a conversao da loja virtual  \
# 0                                     4
# 1                                     3
# 2                                     4
# 3                                     3
# 4                                     4
#
#    potencializar as vendas em canais online como loja virtual whatsapp entre outros  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    acelerar e aumentar as vendas atraves de dados e ferramentas qualificadas  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    riqueza de dados para analise integrada do nosso time de vendas  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Melhorar a experiencia do cliente com uma equipe de atendimento assertiva por meio de ferramentas eficazes  \
# 0                                                  3
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    Mostrar os diferenciais da minha marca para os clientes que desejo objeter  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    criar jornadas personalizadas na segmentacao dos nossos clientes entendendo quem sao e o que querem  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    Marketing de oportunidade eficiente base forte e preparada para o mercado   \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#                     TARGET
# 0  CUSTOMER 360 OU STARTER
# 1  CUSTOMER 360 OU STARTER
# 2  CUSTOMER 360 OU STARTER
# 3  CUSTOMER 360 OU STARTER
# 4  CUSTOMER 360 OU STARTER

# %%
from sklearn.model_selection import train_test_split

# %%
# Escolhendo as colunas preditivas e alvo
x = dados.drop(columns = ['TARGET','empresa']) # Somente Comprimento do Abdômen e Comprimento das Antenas
y = dados['TARGET']                # Classe alvo

# Dividindo conjunto de treinamento e conjunto de teste
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
x_train.head(5)
# Out:
#     estrategias de marketing mais eficientes que mostrem nossa marca para nosso publico alvo  \
# 22                                                  4
# 15                                                  3
# 65                                                  2
# 11                                                  4
# 42                                                  4
#
#     IA e automacoes para auxiliar nas atividades operacionais  \
# 22                                                  3
# 15                                                  4
# 65                                                  4
# 11                                                  4
# 42                                                  2
#
#     desenvolver estrategias de atendimento eficientes  \
# 22                                                  4
# 15                                                  3
# 65                                                  2
# 11                                                  4
# 42                                                  1
#
#     melhorar a comunicacao entre nossos clientes e nossa equipe de atendimento  \
# 22                                                  3
# 15                                                  4
# 65                                                  2
# 11                                                  4
# 42                                                  1
#
#     ambiente integrado para manter as equipes 100 entrosadas  \
# 22                                                  4
# 15                                                  3
# 65                                                  4
# 11                                                  4
# 42                                                  1
#
#     aumento da produtividade da equipe  \
# 22                                   3
# 15                                   4
# 65                                   4
# 11                                   4
# 42                                   2
#
#     melhorar a capacitacao das equipes de CRM  \
# 22                                          4
# 15                                          3
# 65                                          4
# 11                                          3
# 42                                          2
#
#     reducao no custo de suporte e atendimento ao clientes  \
# 22                                                  3
# 15                                                  4
# 65                                                  2
# 11                                                  3
# 42                                                  2
#
#     aumentar a conversao da loja virtual  \
# 22                                     4
# 15                                     3
# 65                                     2
# 11                                     3
# 42                                     1
#
#     potencializar as vendas em canais online como loja virtual whatsapp entre outros  \
# 22                                                  3
# 15                                                  4
# 65                                                  2
# 11                                                  3
# 42                                                  1
#
#     acelerar e aumentar as vendas atraves de dados e ferramentas qualificadas  \
# 22                                                  4
# 15                                                  3
# 65                                                  2
# 11                                                  3
# 42                                                  2
#
#     riqueza de dados para analise integrada do nosso time de vendas  \
# 22                                                  3
# 15                                                  4
# 65                                                  2
# 11                                                  3
# 42                                                  2
#
#     Melhorar a experiencia do cliente com uma equipe de atendimento assertiva por meio de ferramentas eficazes  \
# 22                                                  4
# 15                                                  3
# 65                                                  2
# 11                                                  3
# 42                                                  1
#
#     Mostrar os diferenciais da minha marca para os clientes que desejo objeter  \
# 22                                                  3
# 15                                                  4
# 65                                                  2
# 11                                                  3
# 42                                                  3
#
#     criar jornadas personalizadas na segmentacao dos nossos clientes entendendo quem sao e o que querem  \
# 22                                                  4
# 15                                                  3
# 65                                                  2
# 11                                                  3
# 42                                                  3
#
#     Marketing de oportunidade eficiente base forte e preparada para o mercado
# 22                                                  3
# 15                                                  4
# 65                                                  2
# 11                                                  3
# 42                                                  4

# %%
y_train.head(5)
# Out:
# 22    CUSTOMER 360 OU STARTER
# 15    CUSTOMER 360 OU STARTER
# 65           SLACK E MULESOFT
# 11    CUSTOMER 360 OU STARTER
# 42                  MARKETING
# Name: TARGET, dtype: object

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis #DESCRIMINADOR LINEAR

# %%
lda = LinearDiscriminantAnalysis()  # Criamos o objeto do classificador (não mudamos nenhum hiperpârametro)

lda.fit(x_train,y_train) # Treinamos o classificador passando apenas o conjunto de dados de treinamento
# Out:
# LinearDiscriminantAnalysis()

# %%
# Perceba que estamos passando apenas o x de teste, afinal o algoritmo é que nos dira qual é o y
y_predicoes = lda.predict(x_test)

# %%
y_predicoes
# Out:
# array(['SLACK E MULESOFT', 'CUSTOMER 360 OU STARTER',
#        'SERVICE  ATENDIMENTO AO CLIENTE', 'SLACK E MULESOFT',
#        'SLACK E MULESOFT', 'MARKETING', 'SLACK E MULESOFT',
#        'COMMERCE E VENDAS', 'SLACK E MULESOFT', 'SLACK E MULESOFT',
#        'SERVICE  ATENDIMENTO AO CLIENTE', 'CUSTOMER 360 OU STARTER',
#        'MARKETING', 'CUSTOMER 360 OU STARTER', 'CUSTOMER 360 OU STARTER',
#        'MARKETING', 'SERVICE  ATENDIMENTO AO CLIENTE', 'SLACK E MULESOFT',
#        'MARKETING', 'COMMERCE E VENDAS', 'CUSTOMER 360 OU STARTER',
#        'COMMERCE E VENDAS', 'CUSTOMER 360 OU STARTER',
#        'COMMERCE E VENDAS', 'COMMERCE E VENDAS', 'COMMERCE E VENDAS',
#        'SERVICE  ATENDIMENTO AO CLIENTE', 'COMMERCE E VENDAS',
#        'MARKETING', 'MARKETING'], dtype='<U31')

# %%
y_test
# Out:
# 73                    SLACK E MULESOFT
# 18             CUSTOMER 360 OU STARTER
# 118    SERVICE  ATENDIMENTO AO CLIENTE
# 78                    SLACK E MULESOFT
# 76                    SLACK E MULESOFT
# 31                           MARKETING
# 64                    SLACK E MULESOFT
# 141                  COMMERCE E VENDAS
# 68                    SLACK E MULESOFT
# 82                    SLACK E MULESOFT
# 110    SERVICE  ATENDIMENTO AO CLIENTE
# 12             CUSTOMER 360 OU STARTER
# 36                           MARKETING
# 9              CUSTOMER 360 OU STARTER
# 19             CUSTOMER 360 OU STARTER
# 56                           MARKETING
# 104    SERVICE  ATENDIMENTO AO CLIENTE
# 69                    SLACK E MULESOFT
# 55                           MARKETING
# 132                  COMMERCE E VENDAS
# 29             CUSTOMER 360 OU STARTER
# 127                  COMMERCE E VENDAS
# 26             CUSTOMER 360 OU STARTER
# 128                  COMMERCE E VENDAS
# 131                  COMMERCE E VENDAS
# 145                  COMMERCE E VENDAS
# 108    SERVICE  ATENDIMENTO AO CLIENTE
# 143                  COMMERCE E VENDAS
# 45                           MARKETING
# 30                           MARKETING
# Name: TARGET, dtype: object

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, classification_report

# %%
matriz_confusao = confusion_matrix(y_true = y_test,
                                   y_pred = y_predicoes,
                                   labels=['CUSTOMER 360 OU STARTER','COMMERCE E VENDAS','SERVICE  ATENDIMENTO AO CLIENTE', 'MARKETING', 'SLACK E MULESOFT'])

# %%
# plotando uma figura com a matriz de confusao
figure = plt.figure(figsize=(10, 8))
disp = ConfusionMatrixDisplay(confusion_matrix = matriz_confusao, display_labels=['CUSTOMER 360 OU STARTER','COMMERCE E VENDAS','SERVICE  ATENDIMENTO AO CLIENTE', 'MARKETING', 'SLACK E MULESOFT'])
disp.plot(values_format='d')

# %% [markdown]
# Exemplo 1 - Terceiro passo: transformar os dados
# Dependendo do algoritmo de Aprendizado de Máquina que usamos precisamos modificar os dados para que eles se adequem as premissas do algoritmo.
#
# Existem duas transformações de escalonamento muito utilizadas:
#
# 1) Nomalização (Normalization) - Também conhecido como escalonamento Min-Max no qual o range de valores da coluna irá fica de 0 (min) até 1 (max);
#
# 2) Padronização (Standardization) - Modifica a distribuição para que a média seja igual a zero e desvio padrão igual a 1 (o método subtrai a média de todas as entradas e dividide pelo desvio padrão);
#
# Quando escolher uma ou outra? Depende dos seus dados, seu problema e o algoritmo que você quer usar. Em alguns casos, escalonar ou não os dados não irá mudar a solução do problema! Ao longo do cursos iremos estudar alguns casos...
#
# IMPORTANTE: independentmente do transformador escolhido, ele deve ser fitado apenas sobre os dados de treinamento. Isto é, o treinamento do escalonador deve receber apenas os dados de treinamento x_train. Após o treinamento do escalonador, ele deverá ser usado para transformar os dados x_test também.
